# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams['legend.fontsize'] = 25
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['font.size'] = 30
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.direction'] = 'in'
#plt.rcParams['legend.frameon'] = False
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=['#1b85b8','#ae5a41','#559e83','#c3cb71','#fb9062'])
plt.rcParams['text.color'] = '0.4'

# %% [markdown]
# ## 3a09 ch3

# %%
chip='3a09'
dev='Cryo'
temp='15 mK'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=12.9
dvmax=30.4
Mf=43.54
typ='i2'
phi=np.array([-16.22,-9.1,-1.98,5.15,13.29])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,95,'single-turn \n input coil')
plt.text(29,3,'3A09 ch3')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch3, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch3.pdf')

# %% [markdown]
# ## 3b08 ch3

# %%
chip='3b08'
dev='Cryo'
temp='15'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=12.46
dvmax=32.4
Mf=40.64
typ='NL'
phi=np.array([6.94,14.01,21.01,28.02,35.62])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.tick_params(axis='x', which='both', bottom=True, top=False, left=False, right=False, labelbottom=False, labelleft=False)
#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,100,'non-lossy')
plt.text(29,3,'3B08 ch3')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch3, T=' + f'{temp}' + 'mK [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch3.pdf')

# %% [markdown]
# ## 3c16 ch2

# %%
chip='3c16'
dev='Cryo'
temp='15 mK'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=11.33
dvmax=30.7
Mf=40.58
typ='NLd'
phi=np.array([8.14,15,26,22.39,29.51,36.04])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch2.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch2.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch2.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch2.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch2.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ = ' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ = ' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ = ' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ = ' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ = ' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.tick_params(axis='both', which='both', bottom=True, top=False, left=True, right=False, labelbottom=False, labelleft=False)
#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
#plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,88,'non-lossy \n     + \n damped')
plt.text(29,3,'3C16 ch2')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch2, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.text(28,5,r'$T = 10 \rm \ mK$')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch2.pdf')

# %% [markdown]
# ## 3c16 ch3

# %%
ibmax=11.19
dvmax=30.2
Mf=40.6
typ='Ld'
phi=np.array([8.26,15.03,22.03,28.97,36.58])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch3.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.tick_params(axis='both', which='both', bottom=True, top=False, left=True, right=False, labelbottom=False, labelleft=False)
#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
#plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,88,'   lossy \n     + \n damped')
plt.text(29,3,'3C16 ch3')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch3, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch3.pdf')

# %% [markdown]
# ## 3c20 ch4

# %%
chip='3c20'
dev='Cryo'
temp='10.7 mK'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=11.793
dvmax=29.35
Mf=40.72
typ='L'
phi=np.array([36.16,28.02,20.89,12.75,5.39])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000+abs(min((V2/2)*1000)), label=2)#r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000+abs(min((V/2)*1000)), label=5)#r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000+abs(min((V/2)*1000)), label=4)#r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000+abs(min((V/2)*1000)), label=3)#r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen+0.5)*Ib_gen, (V/2)*1000+abs(min((V/2)*1000)), label=1)#r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$'

plt.tick_params(axis='x', which='both', bottom=True, top=False, left=False, right=False, labelbottom=False, labelleft=False)
#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,100,'lossy')
plt.text(29,3,'3C20 ch4')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch4, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch4.pdf')

# %% [markdown]
# ## 3c25 ch1

# %%
chip='3c25'
dev='Cryo'
temp='15 mK'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=11.69
dvmax=26.2
Mf=40.44
typ='i0d'
phi=np.array([7.12,14.25,21.37,28.49,34])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.tick_params(axis='both', which='both', bottom=True, top=False, left=True, right=False, labelbottom=False, labelleft=False)
#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
#plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,88,'no input coil \n        + \n   damped')
plt.text(29,3,'3C25 ch1')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch1, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch1.pdf')

# %% [markdown]
# ## 3c25 ch4

# %%
ibmax=11.44
dvmax=29.5
Mf=40.18
typ='Lisod'
phi=np.array([7.12,14.25,21.37,28.49,35.86])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.tick_params(axis='y', which='both', bottom=True, top=False, left=True, right=False, labelbottom=False, labelleft=False)
plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
#plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
#plt.ylim(0,40)
#plt.xlim(0,20)
plt.text(2,88,'lossy with $\mathrm{SiO_2}$ \n        + \n   damped')
plt.text(29,3,'3C25 ch4')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch4, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch4.pdf')

# %% [markdown]
# ## 3d13 ch1

# %%
chip='3d13'
dev='Cryo'
temp='15 mK'
Ib_gen=50
Phib_gen=200
x=np.linspace(0, 50, 5000)

ibmax=11.54
dvmax=30.4
Mf=39.7
typ='i0'
phi=np.array([6.11,13.13,20.35,27.48,32.56])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch1.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s} = n\Phi_0$')#r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s} = (n+1/2)\Phi_0$')#r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

#plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
plt.tick_params(axis='x', which='both', bottom=True, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
plt.text(2,100,'no input coil')
plt.text(29,3,'3D13 ch1')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch1, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch1.pdf')

# %% [markdown]
# ## 3d13 ch4

# %%
ibmax=10.309
dvmax=29.7
Mf=40.07
typ='Liso'
phi=np.array([8.14, 15.26, 22.39, 28.49, 34.6])

#IV

t, gen, V = np.loadtxt(open('IV_1_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t2, gen2, V2 = np.loadtxt(open('IV_2_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t3, gen3, V3 = np.loadtxt(open('IV_3_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t4, gen4, V4 = np.loadtxt(open('IV_4_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)
t5, gen5, V5 = np.loadtxt(open('IV_5_' + f'{chip}' + '_ch4.csv').readlines()[:-2], skiprows=4, usecols=(0,1,2), delimiter = ',', unpack=True)

plt.plot((gen+0.5)*Ib_gen, (V/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[0]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen2+0.5)*Ib_gen, (V2/2)*1000-abs(min((V2/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[1]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen3+0.5)*Ib_gen, (V3/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[2]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen4+0.5)*Ib_gen, (V4/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[3]/Mf, 2)}' + '$\Phi_0$')
plt.plot((gen5+0.5)*Ib_gen, (V5/2)*1000-abs(min((V/2)*1000)), label=r'$\Phi_{\rm s}$ =' + f'{round(phi[4]/Mf, 2)}' + '$\Phi_0$')

plt.xlabel(r'bias current $I_{\rm b}$ [µA]')
plt.ylabel(r'voltage $V_{\rm s}$ [µV]')
plt.ylim(0,110)
plt.xlim(0,40)
plt.text(2,100,'lossy with $\mathrm{SiO_2}$')
plt.text(29,3,'3D13 ch4')
#plt.title('FE (' + f'{typ}' + '): IV (' + f'{chip}' + ' ch4, T=' + f'{temp}' + ' [' + f'{dev}' + '])')
#plt.legend(frameon=False)
plt.savefig('IV_' + f'{chip}' + '_ch4.pdf')
